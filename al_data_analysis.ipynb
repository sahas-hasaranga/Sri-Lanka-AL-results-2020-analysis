# %%
import pandas as pd
import sweetviz as sv

# Oyage file eke path eka
file_path = r"C:\Users\ASUS VIVOBOOK\Downloads\2020_al_data_kaggle_upload_new_old_syllabi.csv\2020_al_data_kaggle_upload_new_old_syllabi.csv"

print("Data reading")
# Data tika read karaganna
df = pd.read_csv(file_path)

print("Report creating..")
# Profiling report eka hadanna
report = sv.analyze(df)

# HTML file eka widihata save karala auto open karanna
report.show_html(filepath="profiling_report.html", open_browser=True)
print("finished!")
# Out:
# Data reading
# Report creating..
# Feature: df_index                            |▌         | [  5%]   00:01 -> (00:23 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: stream                              |█         | [ 10%]   00:01 -> (00:16 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: al_year                             |███       | [ 30%]   00:02 -> (00:04 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: sub1                                |███▌      | [ 35%]   00:03 -> (00:03 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: sub1_r                              |████      | [ 40%]   00:03 -> (00:03 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: sub2                                |████▌     | [ 45%]   00:03 -> (00:02 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: sub2_r                              |█████     | [ 50%]   00:03 -> (00:02 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: sub3                                |█████▌    | [ 55%]   00:04 -> (00:02 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: sub3_r                              |██████    | [ 60%]   00:04 -> (00:02 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: cgt_r                               |██████▌   | [ 65%]   00:04 -> (00:02 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: ge_r                                |███████   | [ 70%]   00:05 -> (00:01 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: syllabus                            |███████▌  | [ 75%]   00:05 -> (00:01 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: birth_day                           |████████  | [ 80%]   00:05 -> (00:00 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: birth_month                         |████████▌ | [ 85%]   00:05 -> (00:00 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: birth_year                          |█████████ | [ 90%]   00:05 -> (00:00 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: gender                              |█████████▌| [ 95%]   00:06 -> (00:00 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: gender                              |██████████| [100%]   00:06 -> (00:00 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# [Step 3/3] Generating associations graph     |          | [  0%]   00:00 -> (? left)    findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report profiling_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# finished!

# %%
import pandas as pd

# Oyage file eke path eka
file_path = r"C:\Users\ASUS VIVOBOOK\Downloads\2020_al_data_kaggle_upload_new_old_syllabi.csv\2020_al_data_kaggle_upload_new_old_syllabi.csv"

# Data tika read karaganna
df = pd.read_csv(file_path)

# Rows saha Columns gana balanna
print("ROWS AND COLS (Raw and column):", df.shape)

# Thiyena columns wala nam tika balanna
print("\nCOLUMNS:")
print(df.columns.tolist())

# Data set eke mul raw 5 balanna
print("\nHEAD (Mul raw 5):")
print(df.head())

# Adu (Missing) values thiyenawada kiyala balanna
print("\nMISSING VALUES (Adu data):")
print(df.isnull().sum())
# Out:
# ROWS AND COLS (Raw and column): (337553, 19)
#
# COLUMNS:
# ['index', 'stream', 'Zscore', 'district_rank', 'island_rank', 'al_year', 'sub1', 'sub1_r', 'sub2', 'sub2_r', 'sub3', 'sub3_r', 'cgt_r', 'ge_r', 'syllabus', 'birth_day', 'birth_month', 'birth_year', 'gender']
#
# HEAD (Mul raw 5):
#    index    stream  Zscore district_rank  island_rank  al_year  \
# 0      0      ARTS  -.3550    4336 (NEW)  64994 (NEW)     2020
# 1      1      ARTS  -.2648    4154 (NEW)  62338 (NEW)     2020
# 2      2  COMMERCE  -.4760    6910 (NEW)  37307 (NEW)     2020
# 3      3  COMMERCE  -.1012    5678 (NEW)  30449 (NEW)     2020
# 4      4  COMMERCE   .6014    3269 (NEW)  17010 (NEW)     2020
#
#                 sub1 sub1_r               sub2 sub2_r        sub3 sub3_r  \
# 0  POLITICAL SCIENCE      S  DANCING(BHARATHA)      C       TAMIL      S
# 1  POLITICAL SCIENCE      S     CARNATIC MUSIC      C       TAMIL      C
# 2          ECONOMICS      S   BUSINESS STUDIES      S  ACCOUNTING      S
# 3          ECONOMICS      C   BUSINESS STUDIES      C  ACCOUNTING      S
# 4          ECONOMICS      C   BUSINESS STUDIES      C  ACCOUNTING      B
#
#   cgt_r ge_r syllabus birth_day birth_month birth_year  gender
# 0   056    S      new        31         May       2001  female
# 1   032    C      new        13     January       2002  female
# 2   050    S      new        16      August       2001  female
# 3   034    S      new        16      August       2001  female
# 4   036    S      new         7      August       2000  female
#
# MISSING VALUES (Adu data):
# index               0
# stream              0
# Zscore              0
# district_rank       0
# island_rank         0
# al_year             0
# sub1                0
# sub1_r              0
# sub2                0
# sub2_r              0
# sub3                0
# sub3_r              0
# cgt_r               0
# ge_r                0
# syllabus            0
# birth_day           0
# birth_month         0
# birth_year          0
# gender           1484
# dtype: int64

# %%
df['stream'].value_counts()
# Out:
# stream
# -                         150514
# ARTS                       76547
# COMMERCE                   39877
# BIOLOGICAL SCIENCE         25768
# PHYSICAL SCIENCE           21776
# ENGINEERING TECHNOLOGY     12498
# BIOSYSTEMS TECHNOLOGY       7833
# NON                         2740
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# female         193326
# male           142719
# Major error        24
# Name: count, dtype: int64

# %%
df['cgt_r'].value_counts()
# Out:
# cgt_r
# Absent    76628
# 040       16182
# 042       15931
# 038       15462
# 044       15135
#           ...
# 002           2
# 000           2
# 098           1
# 092           1
# 100           1
# Name: count, Length: 73, dtype: int64
